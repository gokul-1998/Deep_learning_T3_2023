# %% [markdown]
# ![image.png](attachment:image.png)

# %%
- blue -> positive (Wtx>=0)
- red -> negative (wtx<=0)
- weight vector = [0.5,0.5]

find number of misclassified as per decision line?

# solution: 
    - right side is wtx>=0, which is blue in color
    - left is red, wtx<=0, which is red in color
    - there are two points which are wrongly placed.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - given f(w)
